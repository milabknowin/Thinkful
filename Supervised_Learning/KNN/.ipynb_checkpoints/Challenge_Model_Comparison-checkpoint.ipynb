# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
# %matplotlib inline
import math
import seaborn as sns
pd.options.display.float_format = '{:.3f}'.format
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# Suppress annoying harmless error.
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
crime = pd.read_csv('NYC_Offenses_2013.csv')

# %%
crime.head()
# Out:
#                              Table 8  Unnamed: 1      Unnamed: 2  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village       1,861               0
#
#                                Unnamed: 3                    Unnamed: 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
#                     Unnamed: 5 Unnamed: 6           Unnamed: 7  \
# 0                          NaN        NaN                  NaN
# 1                                     NaN                  NaN
# 2                          NaN        NaN                  NaN
# 3  Rape\n(legacy\ndefinition)2    Robbery  Aggravated\nassault
# 4                            0          0                    0
#
#         Unnamed: 8 Unnamed: 9      Unnamed: 10            Unnamed: 11  \
# 0              NaN        NaN              NaN                    NaN
# 1              NaN        NaN              NaN                    NaN
# 2              NaN        NaN              NaN                    NaN
# 3  Property\ncrime   Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft
# 4               12          2               10                      0
#
#   Unnamed: 12 Unnamed: 13
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3      Arson3      Pop_sq
# 4           0   3,463,321

# %%
# delete rows :3

crime = crime.drop(crime.index[[0, 1, 2, 3]])

# %%
# delete last 3 rows

crime = crime.drop(crime.index[[348, 349, 350]])

# %%
# view column names

crime.columns
# Out:
# Index(['Table 8', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
# rename columns

crime = crime.rename(columns={'Table 8' : 'city', 'Unnamed: 1' : 'population', 'Unnamed: 2' : 'violent_crime',
                              'Unnamed: 3' : 'murder', 'Unnamed: 4' : 'rape_revised', 'Unnamed: 5' : 'rape',
                              'Unnamed: 6' :'robbery', 'Unnamed: 7' : 'aggravated_assault',
                              'Unnamed: 8' : 'property_crime','Unnamed: 9' : 'burglary', 'Unnamed: 10' : 'larceny',
                              'Unnamed: 11' : 'vehicle_theft', 'Unnamed: 12' : 'arson', 'Unnamed: 13' : 'pop_sq'})

# %%
# drop pop_sq column from dataset

crime = crime.drop('pop_sq', 1)

# %%
# remove commas from columns

crime = crime.replace(',','', regex=True)

# %%
# verify columns renamed, new columns added to dataset, commas removed & population square column dropped 

crime.head()
# Out:
#                        city population violent_crime murder  rape_revised  \
# 4             Adams Village       1861             0      0           nan
# 5  Addison Town and Village       2577             3      0           nan
# 6             Akron Village       2846             3      0           nan
# 7                    Albany      97956           791      8           nan
# 8            Albion Village       6388            23      0           nan
#
#   rape robbery aggravated_assault property_crime burglary larceny  \
# 4    0       0                  0             12        2      10
# 5    0       0                  3             24        3      20
# 6    0       0                  3             16        1      15
# 7   30     227                526           4090      705    3243
# 8    3       4                 16            223       53     165
#
#   vehicle_theft arson
# 4             0     0
# 5             1     0
# 6             0     0
# 7           142   NaN
# 8             5   NaN

# %%
# verify last 3 rows dropped from table

crime.tail()
# Out:
#                   city population violent_crime murder  rape_revised rape  \
# 347      Woodbury Town      10685             3      0           nan    0
# 348  Woodridge Village        829             7      0           nan    0
# 349     Woodstock Town       5931             2      0           nan    0
# 350            Yonkers     199134          1036      6           nan   25
# 351      Yorktown Town      36643            15      0           nan    0
#
#     robbery aggravated_assault property_crime burglary larceny vehicle_theft  \
# 347       2                  1            541        9     529             3
# 348       0                  7             17        8       9             0
# 349       0                  2             58       13      45             0
# 350     390                615           2368      470    1662           236
# 351       2                 13            334       45     287             2
#
#     arson
# 347   NaN
# 348     0
# 349   NaN
# 350    10
# 351   NaN

# %%
crime['population'].describe()
# Out:
# count      348
# unique     347
# top       9517
# freq         2
# Name: population, dtype: object

# %%
# change population column from object to float

crime['population'] = crime['population'].astype(float)
crime['population'].describe()
# Out:
# count       348.000
# mean      40037.632
# std      450037.368
# min         526.000
# 25%        3003.000
# 50%        7233.500
# 75%       18427.500
# max     8396126.000
# Name: population, dtype: float64

# %%
crime = crime[crime.population < (np.percentile(crime.population, 75))]

# %%
crime['population'].describe()
# Out:
# count     261.000
# mean     6071.218
# std      4471.334
# min       526.000
# 25%      2381.000
# 50%      4704.000
# 75%      8544.000
# max     18182.000
# Name: population, dtype: float64

# %%
# change property crime column from object to float

crime['property_crime'] = crime['property_crime'].astype(float)
crime['property_crime'].describe()
# Out:
# count   261.000
# mean    119.345
# std     140.709
# min       0.000
# 25%      29.000
# 50%      66.000
# 75%     156.000
# max     949.000
# Name: property_crime, dtype: float64

# %%
# change robbery column from object to float

crime['robbery'] = crime['robbery'].astype(float)
crime['robbery'].describe()
# Out:
# count   261.000
# mean      1.632
# std       3.025
# min       0.000
# 25%       0.000
# 50%       0.000
# 75%       2.000
# max      20.000
# Name: robbery, dtype: float64

# %%
# change murder column from object to float

crime['murder'] = crime['murder'].astype(float)
crime['murder'].describe()
# Out:
# count   261.000
# mean      0.054
# std       0.226
# min       0.000
# 25%       0.000
# 50%       0.000
# 75%       0.000
# max       1.000
# Name: murder, dtype: float64

# %%
# change violent crime column from object to float

crime['violent_crime'] = crime['violent_crime'].astype(float)
crime['violent_crime'].describe()
# Out:
# count   261.000
# mean      8.080
# std      12.259
# min       0.000
# 25%       1.000
# 50%       3.000
# 75%       9.000
# max      89.000
# Name: violent_crime, dtype: float64

# %%
# change rape_revised def column from object to float

crime['rape_revised'] = crime['rape_revised'].astype(float)
crime['rape_revised'].describe()
# Out:
# count   0.000
# mean      nan
# std       nan
# min       nan
# 25%       nan
# 50%       nan
# 75%       nan
# max       nan
# Name: rape_revised, dtype: float64

# %%
# drop rape_revised column from dataset without having to reassign df

crime.drop('rape_revised', axis=1, inplace=True)

# %%
# change rape column from object to float

crime['rape'] = crime['rape'].astype(float)
crime['rape'].describe()
# Out:
# count   261.000
# mean      0.705
# std       1.598
# min       0.000
# 25%       0.000
# 50%       0.000
# 75%       1.000
# max      13.000
# Name: rape, dtype: float64

# %%
# change aggravated assault column from object to float

crime['aggravated_assault'] = crime['aggravated_assault'].astype(float)
crime['aggravated_assault'].describe()
# Out:
# count   261.000
# mean      5.690
# std       8.593
# min       0.000
# 25%       0.000
# 50%       3.000
# 75%       7.000
# max      64.000
# Name: aggravated_assault, dtype: float64

# %%
# change burglary column from object to float

crime['burglary'] = crime['burglary'].astype(float)
crime['burglary'].describe()
# Out:
# count   261.000
# mean     19.226
# std      23.494
# min       0.000
# 25%       4.000
# 50%      11.000
# 75%      23.000
# max     138.000
# Name: burglary, dtype: float64

# %%
# change larceny column from object to float

crime['larceny'] = crime['larceny'].astype(float)
crime['larceny'].describe()
# Out:
# count   261.000
# mean     97.736
# std     118.640
# min       0.000
# 25%      20.000
# 50%      53.000
# 75%     121.000
# max     828.000
# Name: larceny, dtype: float64

# %%
# change vehicle theft column from object to float

crime['vehicle_theft'] = crime['vehicle_theft'].astype(float)
crime['vehicle_theft'].describe()
# Out:
# count   261.000
# mean      2.383
# std       3.822
# min       0.000
# 25%       0.000
# 50%       1.000
# 75%       3.000
# max      35.000
# Name: vehicle_theft, dtype: float64

# %%
# change arson column from object to float

crime['arson'] = crime['arson'].astype(float)
crime['arson'].describe()
# Out:
# count   145.000
# mean      0.345
# std       0.861
# min       0.000
# 25%       0.000
# 50%       0.000
# 75%       0.000
# max       5.000
# Name: arson, dtype: float64

# %%
# drop arson column

crime.drop('arson', axis=1, inplace=True)

# %%
# verify rape_revised & arson columns dropped from dataset

crime.head()
# Out:
#                        city  population  violent_crime  murder  rape  robbery  \
# 4             Adams Village    1861.000          0.000   0.000 0.000    0.000
# 5  Addison Town and Village    2577.000          3.000   0.000 0.000    0.000
# 6             Akron Village    2846.000          3.000   0.000 0.000    0.000
# 8            Albion Village    6388.000         23.000   0.000 3.000    4.000
# 9            Alfred Village    4089.000          5.000   0.000 0.000    3.000
#
#    aggravated_assault  property_crime  burglary  larceny  vehicle_theft
# 4               0.000          12.000     2.000   10.000          0.000
# 5               3.000          24.000     3.000   20.000          1.000
# 6               3.000          16.000     1.000   15.000          0.000
# 8              16.000         223.000    53.000  165.000          5.000
# 9               2.000          46.000    10.000   36.000          0.000

# %%
crime.drop_duplicates()
# Out:
#                            city  population  violent_crime  murder  rape  \
# 4                 Adams Village    1861.000          0.000   0.000 0.000
# 5      Addison Town and Village    2577.000          3.000   0.000 0.000
# 6                 Akron Village    2846.000          3.000   0.000 0.000
# 8                Albion Village    6388.000         23.000   0.000 3.000
# 9                Alfred Village    4089.000          5.000   0.000 0.000
# 10             Allegany Village    1781.000          3.000   0.000 0.000
# 12           Amityville Village    9519.000          9.000   0.000 2.000
# 13                    Amsterdam   18182.000         30.000   0.000 0.000
# 14               Arcade Village    2053.000          0.000   0.000 0.000
# 343    0.000               6.000          62.000    12.000   49.000
# 345    0.000               4.000          36.000    14.000   21.000
# 346    0.000               0.000          77.000    13.000   61.000
# 347    2.000               1.000         541.000     9.000  529.000
# 348    0.000               7.000          17.000     8.000    9.000
# 349    0.000               2.000          58.000    13.000   45.000
#
#      vehicle_theft
# 4            0.000
# 5            1.000
# 6            0.000
# 8            5.000
# 9            0.000
# 10           0.000
# 12           6.000
# 13          15.000
# 14           1.000
# 15           1.000
# 16           0.000
# 17           1.000
# 19           2.000
# 20           1.000
# 21           0.000
# 22           2.000
# 23           2.000
# 24           3.000
# 27           0.000
# 28           7.000
# 29           0.000
# 30           0.000
# 31           0.000
# 32           2.000
# 33           0.000
# 34           0.000
# 36           4.000
# 37           3.000
# 38           0.000
# 40           0.000
# ..             ...
# 310          2.000
# 311          0.000
# 312          6.000
# 313          1.000
# 315          4.000
# 316          0.000
# 317          2.000
# 320          2.000
# 321          1.000
# 322          2.000
# 323          0.000
# 324          2.000
# 327          5.000
# 329          0.000
# 330          0.000
# 331          2.000
# 332          1.000
# 333          2.000
# 335         21.000
# 336          2.000
# 337          4.000
# 339          0.000
# 340          3.000
# 341          3.000
# 343          1.000
# 345          1.000
# 346          3.000
# 347          3.000
# 348          0.000
# 349          0.000
#
# [261 rows x 11 columns]

# %%
crime.isnull().sum()
# Out:
# city                  0
# population            0
# violent_crime         0
# murder                0
# rape                  0
# robbery               0
# aggravated_assault    0
# property_crime        0
# burglary              0
# larceny               0
# vehicle_theft         0
# dtype: int64

# %%
crime = crime.dropna()

# %% [markdown]
# ## OLS Regression

# %%
# Instantiate and fit model

regr = linear_model.LinearRegression()
Y = crime['property_crime'].values.reshape(-1, 1)
X = crime[['robbery','burglary','larceny']]
regr.fit(X, Y)

# Inspect the results

print('\nCoefficients: \n', regr.coef_)
print('\nIntercept: \n', regr.intercept_)
print('\nR-squared:')
print(regr.score(X, Y))
# Out:
# Coefficients:
#  [[ 0.29400745  1.04973419  1.00486028]]
#
# Intercept:
#  [ 0.47205298]
#
# R-squared:
# 0.999564228255

# %%
# Extract predicted values

predicted = regr.predict(X).ravel()
actual = crime['property_crime']

# Calculate the error, also called the residual.
residual = actual - predicted

plt.hist(residual)
plt.title('Residual counts')
plt.xlabel('Residual')
plt.ylabel('Count')
plt.show()

# %%
plt.scatter(predicted, residual)
plt.xlabel('Predicted')
plt.ylabel('Residual')
plt.axhline(y=0)
plt.title('Residual vs. Predicted')
plt.show()

# %% [markdown]
# ## KNN Regression

# %%
from sklearn import neighbors
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# Build our model.
knn = neighbors.KNeighborsRegressor(n_neighbors=10)
X = pd.DataFrame(crime.burglary)
Y = crime.property_crime
knn.fit(X, Y)

# Set up prediction line

# is this necessary??

T = np.arange(0, 50, 0.1)[:, np.newaxis]

# Trailing underscores are a common convention for a prediction.
Y_ = knn.predict(T)

plt.scatter(X, Y, c='k', label='data')
plt.plot(T, Y_, c='g', label='prediction')
plt.xticks(rotation=90)
plt.legend()
plt.title('K=10, Unweighted')
plt.show()

# %%
from sklearn import neighbors
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# Build our model.
knn = neighbors.KNeighborsRegressor(n_neighbors=10)
X = pd.DataFrame(crime.burglary)
Y = crime.property_crime
knn.fit(X, Y)

# Set up our prediction line.
#T = np.arange(0, 50, 0.1)[:, np.newaxis]

# Trailing underscores are a common convention for a prediction.
Y_ = knn.predict(X)

plt.scatter(X, Y, label='data')

#plt.plot(X, Y_, c='g', label='prediction')
# removed grasshopper to show only scatter plot

plt.xticks(rotation=90)
plt.legend()
plt.title('K=10, Unweighted')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# Run the same model, this time with weights.
knn_w = neighbors.KNeighborsRegressor(n_neighbors=10, weights='distance')
X = pd.DataFrame(crime.burglary)
Y = crime.property_crime
knn_w.fit(X, Y)

# Set up our prediction line.
T = np.arange(0, 50, 0.1)[:, np.newaxis]

Y_ = knn_w.predict(T)

plt.scatter(X, Y, c='k', label='data')
plt.plot(T, Y_, c='g', label='prediction')
plt.xticks(rotation=90)
plt.legend()
plt.title('K=10, Weighted')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(knn, X, Y, cv=5)
print("Unweighted Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
score_w = cross_val_score(knn_w, X, Y, cv=5)
print("Weighted Accuracy: %0.2f (+/- %0.2f)" % (score_w.mean(), score_w.std() * 2))
# Out:
# Unweighted Accuracy: 0.68 (+/- 0.39)
# Weighted Accuracy: 0.65 (+/- 0.40)

# %% [markdown]
# **Based on the OLS R^2 & KNN accuracy, OLS is the more accurate predictor.  Similarity isn't enough to accurately predict non linear data even with weights. **
